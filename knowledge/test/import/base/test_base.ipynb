# %%
cur = ["a","b","c"]
print("\n".join(cur))
# Out:
# a
# b
# c

# %%
import os
file_path = r"D:\A-py\AI_project\smartku\knowledge\processor\import_process\import_temp_dir\万用表RS-12的使用.pdf"
file_name, file_extension = os.path.splitext(file_path)

print(f"File name: {file_name}")
print(f"File extension: {file_extension}")

image_dir = r"D:\A-py\AI_project\smartku\knowledge\processor\import_process\import_temp_dir"

for i in os.listdir(image_dir):
    file_name, file_extension = os.path.splitext(i)
print(f"File name: {file_name}, Extension: {file_extension}")
# Out:
# File name: D:\A-py\AI_project\smartku\knowledge\processor\import_process\import_temp_dir\万用表RS-12的使用
# File extension: .pdf
# File name: 万用表RS-12的使用, Extension: .pdf
