# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text = "苹果的颜色是红色的[SEP]香蕉的颜色是黄色的[SEP]橘子的颜色是橙色的"

splitter_false = RecursiveCharacterTextSplitter(
    separators=["[SEP]"],
    chunk_size=10,
    chunk_overlap=0,
    keep_separator=False
)
splitter_false.split_text(text)
# Out:
# ['苹果的颜色是红色的', '香蕉的颜色是黄色的', '橘子的颜色是橙色的']

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text = "苹果的颜色是红色的[SEP]香蕉的颜色是黄色的[SEP]橘子的颜色是橙色的"

splitter_true = RecursiveCharacterTextSplitter(
    separators=["[SEP]"],
    chunk_size=10,
    chunk_overlap=0,
    keep_separator=True
)
splitter_true.split_text(text)
# Out:
# ['苹果的颜色是红色的', '[SEP]香蕉的颜色是黄色的', '[SEP]橘子的颜色是橙色的']
